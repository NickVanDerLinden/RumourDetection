# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import nltk
from nltk.tokenize import word_tokenize
from pytwitter import Api
import json
import math

#!pip install emoji
from emoji import UNICODE_EMOJI

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

#API key = z5uFu3NIteA6EBf1ou3LrraTQ
#API key secret = uAPN84aJgdNvPYjXCNpdk07rMDrhYkpc2xw7euaQkXmzL6ZQBw
#bearer token = AAAAAAAAAAAAAAAAAAAAALRUaAEAAAAA0WNStdCEAZ%2FOa5JQTVc%2BnT7P3nY%3D4QvSzmESKEo8KrBF0vczfZn4LgNjIAZvXQbGIwq4pA0kNm3sJG
#Access token = 1488811610542063617-3aFMTFTnQKp3mpOw0wKUc9v2QD624x
#Acces token secret = sWIiaRUSfsVdXQYuVbV4jM0jH5sKChx9vruy0oYpQPxhw

# %%
# Using readline()
file1 = open('#widm.txt', 'r')
count = 0
tweets = []

while True:
    count += 1
 
    # Get next line from file
    line = file1.readline()
 
    # if line is empty
    # end of file is reached
    if not line:
        break
    tweets.append(json.loads(line,encoding="utf-8"))
    
data = []
for i in range(len(tweets)):
    for j in range(len(tweets[i]["data"])):
        temp = []
        if tweets[i]["data"][0]["lang"] == 'nl':
            temp.append(tweets[i]["data"][0])
            user = [k for k in tweets[0]["includes"]["users"] 
                    if k["id"] == tweets[i]["data"][j]["author_id"]]
            temp.append(user)
            data.append(temp)
len(data)
# Out:
# 128417

# %%
import time 
#text = data2[x][0]["text"]

features_widm = []
for x in range(0,len(data)):
    temp = []
    if data[x][1] != []:
        followers_count = data[x][1][0]["public_metrics"]["followers_count"]
        temp.append(followers_count)
    else:
        temp.append(-1)

    if data[x][1] != []:        
        tweetcount = data[x][1][0]["public_metrics"]["tweet_count"]
        temp.append(tweetcount)
    else:
        temp.append(-1)

    qmarks = "?" in data[x][0]["text"]
    temp.append(int(qmarks))

    if data[x][1] != []:
        verified = data[x][1][0]["verified"]
        temp.append(int(verified))    
    else:
        temp.append(-1)
        
    accountlife = time.mktime(time.localtime()) - time.mktime(time.strptime(data[x][0]["created_at"], "%Y-%m-%dT%H:%M:%S.000Z"))
    temp.append(accountlife)

    if data[x][1] != []:    
        ratio = (data[x][1][0]["public_metrics"]["followers_count"]+1)/(data[x][1][0]["public_metrics"]["following_count"]+2)
        temp.append(ratio)
    else:
        temp.append(999999)
        
    emark = "!" in data[x][0]["text"]
    temp.append(int(emark))

    capitalletters = sum(1 for c in data[x][0]["text"] if c.isupper())/sum(1 for c in data[x][0])
    temp.append(capitalletters)

    retweet_count = data[x][0]["public_metrics"]["retweet_count"]
    temp.append(retweet_count)
    
    hashtags = "#" in data[x][0]["text"]
    temp.append(int(hashtags))
    
    if data[x][1] != []:
        following = data[x][1][0]["public_metrics"]["following_count"]
        temp.append(following)
    else:
        temp.append(-1)

    text_length = len(data[x][0]["text"])
    temp.append(text_length)
    
    if data[x][1] != []:    
        listed_count = data[x][1][0]["public_metrics"]["listed_count"]
        temp.append(listed_count)
    else:
        temp.append(-1)

    emoticons = True in [s in UNICODE_EMOJI['en'] for s in data[x][0]["text"]]
    temp.append(int(emoticons))
    
    reply_count = data[x][0]["public_metrics"]["reply_count"]
    temp.append(reply_count)
    
    quote_count = data[x][0]["public_metrics"]["quote_count"]
    temp.append(quote_count)
    
    like_count = data[x][0]["public_metrics"]["like_count"]
    temp.append(like_count)
    
    if data[x][1] != []:
        timeafterposting = time.mktime(time.strptime(data[x][1][0]["created_at"],"%Y-%m-%dT%H:%M:%S.000Z")) - time.mktime(time.strptime(data[x][0]["created_at"],"%Y-%m-%dT%H:%M:%S.000Z"))
        temp.append(timeafterposting)
    else:
        temp.append(999999)

    pos_tags = nltk.pos_tag(nltk.word_tokenize(data[x][0]["text"]))
    temp.append(pos_tags)
    
    activity = tweetcount/accountlife
    temp.append(activity)

    if data[x][1] != []:
        has_url = "profile_image_url" in data[x][1][0]
        temp.append(int(has_url))
    else:
        temp.append(-1)
        
    fpp = True in [i in data[x][0]["text"].lower() for i in ["me", "my", "i", "mine"]]
    temp.append(int(fpp))

    nsfw = data[x][0]["possibly_sensitive"] 
    temp.append(int(nsfw))
    features_widm.append(temp)

# %%
[type(x) for x in features_widm[0]]
# Out:
# [int,
#  int,
#  int,
#  int,
#  float,
#  float,
#  int,
#  float,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  int,
#  float,
#  list,
#  float,
#  int,
#  int,
#  int]

# %%
unique, counts = np.unique([x[0] for x in features_widm], return_counts=True)
plt.plot(unique[1:], counts[1:])
plt.xlabel("follower count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[1] for x in features_widm], return_counts=True)
plt.plot(unique[1:], counts[1:])
plt.xlabel("tweet count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[2] for x in features_widm], return_counts=True)
counts
# Out:
# array([97871, 30546], dtype=int64)

# %%
unique, counts = np.unique([x[3] for x in features_widm], return_counts=True)
counts
# Out:
# array([110842,  16923,    652], dtype=int64)

# %%
unique, counts = np.unique([x[4] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("account life")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[5] for x in features_widm], return_counts=True)
plt.plot(unique[:-1], counts[:-1])
plt.xlabel("ratio")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[6] for x in features_widm], return_counts=True)
counts

#exclamation points
# Out:
# array([105463,  22954], dtype=int64)

# %%
unique, counts = np.unique([x[7] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("capital letter ratio")
plt.xlim(0,1)
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[8] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("retweet_count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[9] for x in features_widm], return_counts=True)
counts

#hashtags
# Out:
# array([  4190, 124227], dtype=int64)

# %%
unique, counts = np.unique([x[10] for x in features_widm], return_counts=True)
plt.plot(unique[1:], counts[1:])
plt.xlabel("following count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[11] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("text length")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[12] for x in features_widm], return_counts=True)
plt.plot(unique[1:], counts[1:])
plt.xlabel("listed count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[13] for x in features_widm], return_counts=True)
counts

#emoticons
# Out:
# array([105606,  22811], dtype=int64)

# %%
unique, counts = np.unique([x[14] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("reply count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[15] for x in features_widm], return_counts=True)
counts

#quote count
# Out:
# array([123074,   4859,    484], dtype=int64)

# %%
unique, counts = np.unique([x[16] for x in features_widm], return_counts=True)
plt.plot(unique, counts)
plt.xlabel("like count")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[17] for x in features_widm], return_counts=True)
counts

plt.plot(unique[:-1], counts[:-1])
plt.xlabel("time after posting")
plt.ylabel("frequency")

#time after posting
# Out:
# Text(0, 0.5, 'frequency')

# %%
unique, counts = np.unique([x[18] for x in features_widm], return_counts=True)
unique

#pos tags
# Out:
# C:\Users\nickv\AppData\Roaming\Python\Python37\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# array([list([('#', '#'), ('RT', 'NNP'), ('@', 'NNP'), ('WieIsDeMol', 'NNP'), (':', ':'), ('Kijk', 'NNP'), ('zaterdag', 'NNP'), ('naar', 'VBD'), ('aflevering', 'VBG'), ('8', 'CD'), ('van', 'JJ'), ('#', '#'), ('widm', 'NN'), ('.', '.'), ('Wie', 'NNP'), ('is', 'VBZ'), ('jouw', 'JJ'), ('#', '#'), ('Mol', 'NNP'), ('?', '.'), ('https', 'NN'), (':', ':'), ('//t.co/Fp3XgCnZvJ', 'NN')]),
#        list([('#', '#'), ('RT', 'NNP'), ('@', 'NNP'), ('WieIsDeMol', 'NNP'), (':', ':'), ('📗', 'NN'), ('‘', 'NNP'), ('Vijf', 'NNP'), ('afleveringen', 'NN'), ('lang', 'NN'), ('was', 'VBD'), ('ik', 'JJ'), ('de', 'FW'), ('hoofdrolspeler', 'NN'), ('in', 'IN'), ('mijn', 'NN'), ('eigen', 'NN'), ('film.', 'NN'), ('’', 'NNP'), ('Lees', 'NNP'), ('het', 'VBD'), ('dagboek', 'JJ'), ('van', 'NN'), ('de', 'IN'), ('vijfde', 'FW'), ('afvaller', 'NN'), ('⬇️', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/eVMkoajXWo', 'NN')]),
#        list([('#', '#'), ('Widm', 'NNP'), ('terugkijken', 'NN'), ('!', '.'), ('!', '.')]),
#        list([('#', '#'), ('kpop', 'NN'), ('is', 'VBZ'), ('weer', 'JJ'), ('bezig', 'NN'), ('om', 'RB'), ('#', '#'), ('widm', 'JJ'), ('te', 'NN'), ('bashen', 'NN'), ('....', 'NN')]),
#        list([('#', '#'), ('linkorama', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('poul', 'NN'), ('Meedoen', 'NNP'), ('?', '.'), ('?', '.'), ('?', '.'), ('https', 'NN'), (':', ':'), ('//t.co/sNUWQwlToZ', 'JJ'), ('#', '#'), ('mollenjacht', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('Moltalk', 'NN')]),
#        list([('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('widm2019', 'JJ'), ('Wat', 'NNP'), ('schreeuwde', 'NN'), ('Sarah', 'NNP'), ('bij', 'NN'), ('de', 'IN'), ('Tokelbaan', 'NNP'), ('?', '.'), ('Hoorde', 'NNP'), ('iets', 'VBZ'), ('van', 'FW'), ('MOL', 'NNP'), ('?', '.'), ('?', '.'), ('?', '.')]),
#        list([('#', '#'), ('moltalk', 'NN'), ('Johan', 'NNP'), ('is', 'VBZ'), ('naar', 'JJ'), ('huis', 'NN'), (',', ','), ('maar', 'FW'), ('gelukkig', 'FW'), ('hebben', 'NN'), ('we', 'PRP'), ('Nathan', 'NNP'), ('nog', 'VBP'), ('die', 'VB'), ('even', 'RB'), ('wat', 'JJ'), ('liefs', 'NNS'), ('over', 'IN'), ('de', 'FW'), ('afvaller', 'FW'), ('zegt', 'NN'), (';', ':'), (')', ')'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('widm2020', 'NN')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm2019', 'JJ'), ('#', '#'), ('WieIsDeMol', 'NNP'), ('Doordraaien', 'NNP'), ('oke', 'VBD'), ('opletten', 'JJ'), ('wie', 'JJ'), ('door', 'NN'), ('draait', 'NN'), ('....', 'NN')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm2021', 'NN'), ('dit', 'NN'), ('is', 'VBZ'), ('zo', 'JJ'), ('verwarrend', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/cLuPz1Yb2t', 'NN')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('Nathan', 'NNP'), ('had', 'VBD'), ('de', 'VBN'), ('leiding', 'VBG'), ('...', ':'), ('De', 'NNP'), ('titel', 'FW'), ('van', 'FW'), ('de', 'FW'), ('aflevering', 'VBG'), ('is', 'VBZ'), ('mis-leiding', 'NN'), ('...', ':')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('Patrick', 'NNP'), ('roept', 'VBZ'), ('``', '``'), ('ik', 'JJ'), ('ben', 'NN'), ('de', 'FW'), ('mol', 'FW'), ("''", "''"), ('en', 'IN'), ('verwijst', 'FW'), ('naar', 'FW'), ('de', 'FW'), ('eerste', 'FW'), ('opdracht', 'FW'), ('....', 'FW'), ('En', 'NNP'), ('stiekem', 'NN'), ('natuurlijk', 'NN'), ('ook', 'NN'), ('naar', 'NN'), ('zichzelf', 'NN'), ('...', ':')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('Wegstoppen', 'NNP'), ('Weg', 'NNP'), ('stoppen', 'JJ'), ('Splinter', 'NNP'), ('en', 'NN'), ('Marije', 'NNP')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('bij', 'NN'), ('de', 'IN'), ('groepsfoto', 'NN'), ('had', 'VBD'), ('jaike', 'NN'), ('vuisten', 'NN'), ('.', '.'), ('‘', 'CC'), ('afgeschermd', 'JJ'), ('’', 'NNP'), ('😏😉', 'NNP'), ('#', '#'), ('nualtunnelvisie', 'NN')]),
#        list([('#', '#'), ('widm', 'JJ'), ('#', '#'), ('widm2020', 'JJ'), ('Ron', 'NNP'), ('vroeg', 'NN'), ('goede', 'NN'), ('vragen', 'NN'), ('!', '.'), ('Ellie', 'NNP'), ('is', 'VBZ'), ('sterk', 'JJ'), ('met', 'JJ'), ('vragen', 'NN'), ('!', '.'), ('!', '.'), ('!', '.')]),
#        list([('#', '#'), ('widm', 'JJ'), ('Wanneer', 'NNP'), ('de', 'FW'), ('leerstof', 'FW'), ('niet', 'JJ'), ('in', 'IN'), ('de', 'JJ'), ('toets', 'NNS'), ('voorkomt', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/xa7b76UNCk', 'NN')]),
#        list([('#', '#'), ('widm', 'JJ'), ('splinter', 'NN'), (':', ':'), ('doet', 'NN'), ('allemaal', 'NN'), ('extra', 'JJ'), ('moeite', 'NN'), ('omdat', 'NN'), ('hij', 'NN'), ('graag', 'NN'), ('penningmeester', 'NN'), ('wil', 'VBD'), ('worden', 'JJ'), ('de', 'FW'), ('groep', 'NN'), (':', ':'), ('erik', 'NN'), ('wordt', 'NN'), ('penningmeester', 'NN'), ('splinter', 'NN'), (':', ':'), ('https', 'NN'), (':', ':'), ('//t.co/62tGzpBiq4', 'NN')]),
#        list([('#', '#'), ('widm', 'NN'), ('Ha', 'NNP'), (',', ','), ('I', 'PRP'), ('knew', 'VBD'), ('it', 'PRP'), ('.', '.'), ('Nooit', 'NNP'), ('de', 'IN'), ('montage', 'NN'), ('vertrouwen', 'NN'), ('.', '.'), ('😁', 'NN')]),
#        list([('#', '#'), ('widm', 'NN'), ('Ik', 'NNP'), ('vind', 'NN'), ('Jeroen', 'NNP'), ('een', 'NN'), ('goede', 'NN'), ('mol', 'NN'), (',', ','), ('vele', 'FW'), ('malen', 'FW'), ('beter', 'NN'), ('dan', 'NN'), ('de', 'IN'), ('vorige', 'FW'), ('.', '.')]),
#        list([('#', '#'), ('widm', 'NN'), ('Moge', 'NNP'), ('vrij', 'NN'), ('duidelijk', 'NN'), ('zijn', 'NN'), ('wie', 'NN'), ('nu', 'FW'), ('de', 'FW'), ('Mol', 'NNP'), ('is', 'VBZ'), ('.', '.'), ('Enige', 'NNP'), ('andere', 'RB'), ('mogelijkheid', 'NN'), ('is', 'VBZ'), ('als', 'NNS'), ('Splinter', 'NNP'), ('al', 'NN'), ('die', 'NN'), ('tijd', 'NN'), ('heeft', 'VBD'), ('kunnen', 'JJ'), ('surfen', 'JJ'), ('op', 'NN'), ('de', 'IN'), ('acties', 'NNS'), ('van', 'VBP'), ('Charlotte', 'NNP'), ('(', '('), ('maar', 'JJ'), ('dan', 'NN'), ('zou', 'NN'), ('ze', 'NN'), ('wel', 'NN'), ('heel', 'NN'), ('dom', 'NN'), ('zijn', 'NNP'), ('geweest', 'NN'), (')', ')'), ('.', '.'), ('Maar', 'NNP'), ('Rocky', 'NNP'), ('en', 'FW'), ('Renee', 'NNP'), ('zijn', 'NNP'), ('t', 'NN'), ('sowieso', 'NN'), ('niet', 'JJ'), (',', ','), ('hangen', 'JJ'), ('maar', 'NN'), ('wat', 'NN'), ('rond', 'NN'), ('.', '.')]),
#        list([('#', '#'), ('widm', 'NN'), ('Renee', 'NNP'), ('komt', 'NNP'), ('aanlopen', 'JJ'), ('met', 'VBD'), ('een', 'JJ'), ('zwart', 'NNP'), ("'vestje", 'NNP'), ("'", 'POS'), ('en', 'NN'), ('2', 'CD'), ('tellen', 'NN'), ('later', 'RB'), ('is', 'VBZ'), ('het', 'JJ'), ('zwart', 'NN'), ('met', 'VBD'), ('witte', 'JJ'), ('stippen', 'JJ'), ('......', 'NN'), ('ehhh', 'NN')]),
#        list([('#', '#'), ('widm', 'NN'), ('een', 'JJ'), ('politiemol', 'NN'), ('dit', 'NN'), ('jaar', 'NN'), ('?', '.'), ('“', 'JJ'), ('Kijk', 'NNP'), ('ik', 'NN'), ('recht', 'NN'), ('in', 'IN'), ('je', 'NN'), ('ogen', 'NN'), ('en', 'FW'), ('weet', 'NN'), ('ik', 'NN'), ('wie', 'NN'), ('je', 'NN'), ('bent', 'NN'), ('”', 'NNP'), ('-', ':'), ('Ellie', 'NNP'), ('Lust', 'NNP')]),
#        list([('#', '#'), ('widm', 'NN'), ('ik', 'NN'), ('blijf', 'NN'), ('ook', 'NN'), ('deze', 'NN'), ('week', 'NN'), ('op', 'RB'), ('#', '#'), ('claes', 'NN'), ('staan', 'NN'), ('....', 'NNP'), ('hij', 'NN'), ('doet', 'NN'), ('zich', 'NNP'), ('teveel', 'NN'), ('als', 'NNS'), ('geen', 'JJ'), ('mol', 'JJ'), ('voor', 'NN'), ('en', 'IN'), ('bovendien', 'NN'), ('was', 'VBD'), ('in', 'IN'), ('dat', 'JJ'), ('zakje', 'NN'), ('blazen', 'NN'), ('ook', 'NN'), ('vreemd', 'NN'), ('.', '.'), ('Ook', 'NNP'), ('een', 'JJ'), ('mol', 'NN'), ('ademt', 'NN'), ('zijn', 'NN'), ('eigen', 'NN'), ('zuurstof', 'NNP'), ('weer', 'NN'), ('in', 'IN'), ('.', '.')]),
#        list([('#', '#'), ('widm', 'NN'), ('kijken', 'VBN'), ('onder', 'MD'), ('genot', 'VB'), ('van', 'JJ'), ('#', '#'), ('minosouro', 'JJ'), ('#', '#'), ('circusmaximus', 'NN'), ('@', 'NNP'), ('maximusbrouwerij', 'NN'), ('#', '#'), ('lowalcoholic', 'JJ'), ('#', '#'), ('sourale', 'JJ'), ('#', '#'), ('craftbeer', 'NN'), ('#', '#'), ('instabeer', 'NN'), ('#', '#'), ('untappd', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/Knmn2ZRnsP', 'NN')]),
#        list([('#', '#'), ('widm', 'NN'), ('mijn', 'NN'), ('mol', 'NN'), ('!', '.'), ('https', 'NN'), (':', ':'), ('//t.co/uwTwZnGNfz', 'NN')]),
#        list([('#', '#'), ('widm', 'NN'), ('opdrachten', 'RB'), ('be', 'VB'), ('like', 'IN'), (':', ':'), ("''", "''"), ('Rij', 'NNP'), ('naar', 'FW'), ('het', 'NN'), ('zuiden', 'NN'), ('.', '.'), ('Daar', 'NNP'), ('ligt', 'VBD'), ('een', 'JJ'), ('kaart', 'NN'), ('.', '.'), ('Deze', 'NNP'), ('moet', 'NN'), ('je', 'NN'), ('ruilen', 'VBN'), ('met', 'VBD'), ('een', 'JJ'), ('plek', 'NN'), ('in', 'IN'), ('het', 'NN'), ('oosten', 'NN'), ('.', '.'), ('Ga', 'NNP'), ('vervolgens', 'VBZ'), ('naar', 'JJ'), ('het', 'NN'), ('westen', 'JJ'), ('om', 'FW'), ('De', 'NNP'), ('Chinese', 'NNP'), ('Muur', 'NNP'), ('na', 'TO'), ('te', 'VB'), ('bouwen', 'NN'), ('.', '.'), ('Zwem', 'NNP'), ('vervolgens', 'VBZ'), ('richting', 'VBG'), ('het', 'JJ'), ('noorden', 'JJ'), ('waar', 'NN'), ('je', 'NN'), ('€150', 'NNP'), ('kunt', 'NN'), ('verdienen', 'NN'), ("''", "''"), ('Jullie', 'NNP'), ('hebben', 'VBD'), ('10', 'CD'), ('minuten', 'NNS'), ('.', '.')]),
#        list([('#', '#'), ('widm', 'NN'), ('rob', 'NN'), ('zegt', 'NN'), ('ik', 'NN'), ('ben', 'NN'), ('een', 'JJ'), ('echte', 'RB'), ('visser', 'VBP'), ('zou', 'NN'), ('dat', 'NN'), ('afleiden', 'NN'), ('naar', 'NN'), ('Suzan', 'NNP'), ('Visser', 'NNP'), ('die', 'NN'), ('de', 'FW'), ('mol', 'NN'), ('was', 'VBD'), ('in', 'IN'), ('2014', 'CD'), ('mmmmmmmh', 'NN'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('#', '#'), ('widm2019', 'JJ'), ('#', '#'), ('widm', 'NN'), ('kwartet', 'NN'), ('nummer', '$'), ('2', 'CD'), ('https', 'NN'), (':', ':'), ('//t.co/TtqArtMjOv', 'NN')]),
#        list([("'Goede", 'CD'), ('tijden', 'NN'), (',', ','), ('slechte', 'JJ'), ('tijden', 'NN'), ('met', 'VBD'), ('Ellie', 'NNP'), ('.', '.'), ("'", "''"), ('#', '#'), ('widm', 'NN')]),
#        list([('.', '.'), ('@', 'VB'), ('rikvdwestelaken', 'JJ'), ('gaat', 'NN'), ('ook', 'NN'), ('volgend', 'VBP'), ('jaar', 'NN'), ('Wie', 'NNP'), ('is', 'VBZ'), ('de', 'FW'), ('Mol', 'NNP'), ('?', '.'), ('presenteren', 'NN'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/FGL0LT7edY', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/I8TKSUMPsE', 'NN')]),
#        list([('2', 'CD'), ('kandidaten', 'JJ'), ('naar', 'JJ'), ('huis', 'NN'), ('💻', 'NNP'), ('❎💻❎', 'NNP'), ('#', '#'), ('widm', 'NN')]),
#        list([('4', 'CD'), ('finalisten', 'NNS'), (',', ','), ('20e', 'CD'), ('seizoen', 'NN'), ('.', '.'), ('4', 'CD'), ('+', 'JJ'), ('20', 'CD'), ('=', 'JJ'), ('24', 'CD'), ('.', '.'), ('De', 'NNP'), ('leeftijd', 'FW'), ('van', 'NN'), ('Buddy', 'NNP'), ('tijdens', 'VBZ'), ('de', 'FW'), ('opnames', 'FW'), ('....', 'FW'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('@', 'JJ'), ('IkBenMilan05', 'NNP'), ('Toch', 'NNP'), ('is', 'VBZ'), ('dat', 'JJ'), ('de', 'FW'), ('enige', 'FW'), ('opdracht', 'FW'), ('die', 'FW'), ('geld', 'NN'), ('heeft', 'NN'), ('opgeleverd', 'NN'), (',', ','), ('dus', 'NN'), ('..', 'NNP'), ('#', '#'), ('widm', 'NN')]),
#        list([('@', 'JJ'), ('JackForrest1978', 'NNP'), ('Het', 'NNP'), ('kan', 'VBD'), ('op', 'JJ'), ('tv', 'NN'), ('nooit', 'NNS'), ('teveel', 'NN'), ('over', 'IN'), ('wie', 'NN'), ('is', 'VBZ'), ('de', 'JJ'), ('mol', 'FW'), (',', ','), ('gaan', 'FW'), ('#', '#'), ('widm', 'NN')]),
#        list([('@', 'JJ'), ('NannoBouma', 'NNP'), ('@', 'NNP'), ('NOS', 'NNP'), ('100', 'CD'), ('%', 'NN'), ('met', 'VBD'), ('je', 'NN'), ('eens', 'NNS'), ('.', '.'), ('Begrijp', 'NNP'), ('de', 'IN'), ('supporters', 'NNS'), ('helemaal', 'VBP'), ('hoor', 'NN'), ('!', '.'), ('!', '.'), ('.', '.'), ('Zit', 'NNP'), ('hier', 'JJR'), ('ook', 'NN'), ('te', 'NN'), ('schreeuwen', 'NN'), ('bij', 'NN'), ('#', '#'), ('WIDM', 'NNP'), ('.', '.'), ('Maar', 'NNP'), ('het', 'JJ'), ('kan', 'VBD'), ('Corona-technisch', 'NNP'), ('gezien', 'NN'), ('nog', 'NN'), ('niet', 'JJ'), ('in', 'IN'), ('een', 'JJ'), ('stadion', 'NN'), ('.', '.'), ('IMHO', 'NN')]),
#        list([('@', 'JJ'), ('NielsonMusic', 'NNP'), ('Niels', 'NNP'), ('is', 'VBZ'), ('vanaf', 'JJ'), ('het', 'JJ'), ('begin', 'NN'), ('mijn', 'NN'), ('mol', 'NN'), ('...', ':'), ('#', '#'), ('widm', 'NN')]),
#        list([('@', 
 'JJ'), ('#', '#'), ('widm', 'JJ'), ('Maar', 'NNP'), ('alvast', 'NN'), ('het', 'NN'), ('nieuwe', 'RB'), ('#', '#'), ('molboekje', 'JJ'), ('bestellen', 'NN'), ('#', '#'), ('trustnoone', 'NN'), ('#', '#'), ('voorbereiding', 'VBG'), ('https', 'NN'), (':', ':'), ('//t.co/Fs9DIdY7Co', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/b7i2cPpC3v', 'NN')]),
#        list([('Blijft', 'NNP'), ('een', 'JJ'), ('vreemd', 'NN'), ('programma', 'NN'), ('.', '.'), ('Totaal', 'NNP'), ('#', '#'), ('vooropgezet', 'NN'), ('en', 'RB'), ('#', '#'), ('doorgestokenkaart', 'JJ'), ('#', '#'), ('widm', 'NN'), ('.', '.'), ('Maar', 'NNP'), ('ja', 'NN'), ('....', 'NNP'), ('kijk', 'VBZ'), ('vooral', 'JJ'), ('....', 'NNP'), ('en', 'FW'), ('laat', 'NN'), ('je', 'NN'), ('beetnemen', 'NNS'), ('....', 'VBP')]),
#        list([('Buddy', 'NNP'), (',', ','), ('Miljuschka', 'NNP'), ('en', 'FW'), ('Nathan', 'NNP'), ('zetten', 'NN'), ('in', 'IN'), ('op', 'JJ'), ('Rob', 'NNP'), ('als', 'NNS'), ('mol', 'NN'), ('.', '.'), ('Rob', 'NNP'), ('op', 'JJ'), ('zijn', 'NN'), ('beurt', 'NN'), ('Buddy', 'NNP'), ('.', '.'), ('Met', 'NNP'), ('1', 'CD'), ('winnaar', 'NN'), (',', ','), ('2', 'CD'), ('verliezers', 'NNS'), ('en', 'VBP'), ('1', 'CD'), ('mol', 'NN'), ('zijn', 'NN'), ('volgens', 'NNS'), ('het', 'VBP'), ('standaard', 'RB'), ('#', '#'), ('widm-protocol', 'JJ'), ('Miljuschka', 'NNP'), ('en', 'FW'), ('Nathan', 'NNP'), ('𝙣𝙞𝙚𝙩', 'NNP'), ('de', 'IN'), ('mol', 'FW'), ('.', '.'), ('Daar', 'NNP'), ('ben', 'NN'), ('ik', 'NN'), ('dan', 'NN'), ('mooi', 'NN'), ('klaar', 'NN'), ('mee', 'NN'), (',', ','), ('want', 'VBP'), ('nu', 'JJ'), ('moet', 'NN'), ('ik', 'NN'), ('switchen', 'NN'), ('.', '.')]),
#        list([('Buddy', 'NNP'), ('heeft', 'VBD'), ('een', 'JJ'), ('zwarte', 'NNP'), ('vrijstelling', 'VBG'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Charlotte', 'NNP'), ('Nijs', 'NNP'), ('zou', 'NNP'), ('het', 'NN'), ('volgende', 'NN'), ("'slachtoffer", 'POS'), ("'", 'POS'), ('van', 'NN'), ('de', 'IN'), ('Molloten', 'NNP'), ('zijn', 'NNP'), ('in', 'IN'), ('de', 'NNP'), ('zoektocht', 'NNP'), ('naar', 'FW'), ('de', 'FW'), ('kandidaten', 'FW'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('charlottenijs', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/LGjlbj2Pzh', 'NN')]),
#        list([('Claes', 'NNP'), ('geeft', 'VBD'), ('@', 'NNP'), ('DeTunnelvisie', 'NNP'), ('de', 'FW'), ('schuld', 'FW'), ('van', 'FW'), ('zijn', 'FW'), ('exit', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Daar', 'NNP'), ('gaan', 'NN'), ('we', 'PRP'), ('.', '.'), ('Veel', 'NNP'), ('plezier', 'JJ'), ('met', 'VBD'), ('de', 'FW'), ('zevende', 'FW'), ('aflevering', 'VBG'), ('van', 'NN'), ('#', '#'), ('widm', 'NN'), ('!', '.')]),
#        list([('Daar', 'NNP'), ('gaan', 'NN'), ('we', 'PRP'), ('😎😁', 'VBP'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/eOKwF0hmjL', 'NN')]),
#        list([('Daar', 'NNP'), ('gaat', 'NN'), ("m'n", 'NN'), ('mol', 'NN'), ('!', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Daar', 'NNP'), ('gingen', 'NN'), ('veel', 'NN'), ('punten', 'VBP'), ('😩', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Dag', 'NNP'), ('Ron', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('widm2020', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('https', 'NN'), (':', ':'), ('//t.co/StKzxVej3b', 'NN')]),
#        list([('Dat', 'NNP'), ('duivelse', 'JJ'), ('lachje', 'NN'), ('van', 'NN'), ('Charlotte', 'NNP'), ('toen', 'NN'), ('Rocky', 'NNP'), ('bij', 'NN'), ('het', 'NN'), ('rad', 'NN'), ('zei', 'NN'), ('``', '``'), ('leuk', 'JJ'), ('als', 'NNS'), ('we', 'PRP'), ('samen', 'VBP'), ('naar', 'FW'), ('de', 'FW'), ('finale', 'FW'), ('gaan', 'NN'), ("''", "''"), ('zegt', 'NN'), ('genoeg', 'NN'), ('.', '.'), ('Ze', 'NNP'), ('wist', 'JJ'), ('al', 'NN'), ('dat', 'NN'), ('ze', 'NN'), ('zelf', 'PRP'), ('naar', 'FW'), ('de', 'FW'), ('finale', 'FW'), ('zou', 'NN'), ('gaan', 'NN'), (',', ','), ('WANT', 'NNP'), ('ZIJ', 'NNP'), ('IS', 'NNP'), ('DE', 'NNP'), ('MOL', 'NNP'), ('!', '.'), ('!', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('De', 'NNP'), ('#', '#'), ('widm-app', 'JJ'), ('doet', 'NN'), ('het', 'NN'), ('!', '.'), ('😊', 'NN')]),
#        list([('De', 'NNP'), ('Alles', 'NNP'), ('Combineren-taart', 'NNP'), ('t/m', 'NN'), ('aflevering', 'VBG'), ('8', 'CD'), ('!', '.'), ('Alle', 'NNP'), ('mogelijke', 'VBD'), ('manieren', 'JJ'), ('om', 'FW'), ('de', 'FW'), ('Mol', 'NNP'), ('te', 'CC'), ('vinden', 'JJ'), ('samenvoegt', 'NN'), ('tot', 'NN'), ('één', 'NNP'), ('grafiek', 'NN'), ('.', '.'), ('Dan', 'NNP'), ('blijkt', 'NN'), ('dat', 'NN'), ('Merel', 'NNP'), ('de', 'IN'), ('meest', 'JJS'), ('waarschijnlijke', 'NN'), ('Mol', 'NNP'), ('is', 'VBZ'), ('met', 'VBN'), ('39,1', 'CD'), ('%', 'NN'), ('!', '.'), ('Sarah', 'NNP'), ('volgt', 'VBD'), ('met', 'VBD'), ('35,5', 'CD'), ('%', 'NN'), ('en', 'JJ'), ('Niels', 'NNP'), ('met', 'VBD'), ('25,3', 'CD'), ('%', 'NN'), ('.', '.'), ('Het', 'NNP'), ('blijft', 'NN'), ('dus', 'NN'), ('spannend', 'NN'), ('!', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('https', 'NN'), (':', ':'), ('//t.co/moYrY2YNzE', 'NN')]),
#        list([('De', 'NNP'), ('aflevering', 'VBG'), ('heet', 'NN'), ("'Met", 'CD'), ('zand', 'NN'), ("strooien'", 'NN'), ('Ik', 'NNP'), ('ben', 'NN'), ('eruit', 'NN'), ('Klaas', 'NNP'), ('Vaak', 'NNP'), ('is', 'VBZ'), ('de', 'JJ'), ('mol', 'FW'), ('...', ':'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([
), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('nathan', 'NN')]),
#        list([('De', 'NNP'), ('mol', 'NNP'), ('weet', 'NN'), ('natuurlijk', 'JJ'), ('dat', 'NN'), ('er', 'NN'), ('meer', 'NN'), ('dezelfde', 'NN'), ('kaarten', 'VBN'), ('in', 'IN'), ('omloop', 'NN'), ('zijn', 'NN'), (',', ','), ('met', 'VBD'), ('andere', 'RB'), ('bedragen', 'NN'), ('.', '.'), ('Dus', 'NNP'), ('pakt', 'NN'), ('de', 'FW'), ('kleinste', 'FW'), ('bedragen', 'NN'), ('eerst', 'RB'), ('en', 'VBZ'), ('gaat', 'NN'), ('die', 'NN'), ('meteen', 'JJ'), ('op', 'FW'), ('de', 'FW'), ('kiek', 'FW'), ('zetten', 'FW'), ('..', 'FW'), ('he', 'PRP'), ('jeroen', 'VBZ'), ('&', 'CC'), ('amp', 'NN'), (';', ':'), ('patrick', 'CC'), ('?', '.'), ('😉', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('De', 'NNP'), ('rode', 'NN'), ('draad', 'NN'), ('bij', 'NN'), ('Splinter', 'NNP'), ('zit', 'NNP'), ('m', 'NN'), ('toch', 'NN'), ('ook', 'NN'), ('in', 'IN'), ('zijn', 'JJ'), ('joker-achtige', 'JJ'), ('outfits', 'NNS'), ('.', '.'), ('Die', 'NNP'), ('van', 'NN'), ('deze', 'NN'), ('week', 'NN'), ('had', 'VBD'), ('ook', 'VBN'), ('nog', 'RB'), ('letterlijk', 'JJ'), ('een', 'JJ'), ('naald', 'NN'), ('en', 'IN'), ('rode', 'NN'), ('draad', 'NN'), ('als', 'NNS'), ('dessin', 'VBP'), ('#', '#'), ('widm2021', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/mBvauDEgIs', 'NN')]),
#        list([('De', 'NNP'), ('titel', 'NN'), ('is', 'VBZ'), ('“', 'JJ'), ('tegendraads', 'NNS'), ('”', 'VBP'), ('.', '.'), ('Buddy', 'NNP'), ('is', 'VBZ'), ('tegendraads', 'NNS'), (',', ','), ('omdat', 'JJ'), ('hij', 'NN'), ('nu', 'NN'), ('al', 'NN'), ('wil', 'NN'), ('wisselen', 'WRB'), ('van', 'NN'), ('roommates', 'VBZ'), ('.', '.'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Deventenaar', 'NNP'), ('@', 'NNP'), ('RobDekay', 'NNP'), ('is', 'VBZ'), ('#', '#'), ('demol', 'NN'), ('.', '.'), ('Wat', 'NNP'), ('een', 'JJ'), ('eindbaas', 'RB'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'NN')]),
#        list([('Dit', 'NNP'), ('vind', 'NN'), ('in', 'IN'), ('echt', 'JJ'), ('HEEL', 'NNP'), ('erg', 'FW'), ('jammer', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Droomde', 'NNP'), ('vanmiddag', 'NN'), ('dat', 'NN'), ('#', '#'), ('Buddy', 'NNP'), ('de', 'FW'), ('Mol', 'NNP'), ('was', 'VBD'), ('.', '.'), ('Haha', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('middagdutje', 'NN')]),
#        list([('Dus', 'NNP'), ('hierom', 'NN'), ('heeft', 'NN'), ('nikkie', 'NN'), ('een', 'JJ'), ('vrijstelling', 'VBG'), ('niet', 'JJ'), ('ingezet', 'NN'), ('.', '.'), ('Ze', 'NNP'), ('heeft', 'VBD'), ('stukje', 'JJ'), ('jeroen', 'NN'), ('gezien', 'NN'), ('.', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Dus', 'NNP'), ('toch', 'NN'), ('twee', 'NN'), ('mollen', 'VBN'), ('dit', 'NN'), ('jaar', 'NN'), ('!', '.'), ('Extra', 'NNP'), ('seizoen', 'VBD'), ('na', 'FW'), ('de', 'FW'), ('zomer', 'FW'), ('!', '.'), ('Met', 'NNP'), ('onbekende', 'IN'), ('nederlanders', 'NNS'), ('?', '.'), ('?', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('@', 'NNP'), ('TrustNobodycast', 'NNP'), ('@', 'NNP'), ('DeTunnelvisie', 'NNP')]),
#        list([('Eindconclusie', 'NN'), (':', ':'), ('Merel', 'NNP'), ('kan', 'VBP'), ('beter', 'NN'), ('actrice', 'NN'), ('worden', 'JJ'), ('dan', 'NN'), ('nieuwslezeres', 'NNS'), ('zijn', 'VBP'), ('.', '.'), ('😅', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('En', 'NNP'), ('Splinter', 'NNP'), ('Chabot', 'NNP'), ('.', '.'), ('Maar', 'NNP'), ('daar', 'NN'), ('houdt', 'NN'), ('het', 'NN'), ('bij', 'NN'), ('ook', 'NN'), ('op', 'NN'), ('RT', 'NNP'), ('@', 'NNP'), ('ivarb98', 'NN'), (':', ':'), ('Ik', 'NNP'), ('ken', 'VB'), ('alleen', 'JJ'), ('Erik', 'NNP'), ('de', 'FW'), ('Zwart🤷🏼\u200d♂️🤷🏼\u200d♂️', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Even', 'RB'), ('serieus', 'NN'), (',', ','), ('die', 'VB'), ('landschap/steden', 'JJ'), ('shots', 'NNS'), ('zijn', 'VBP'), ('echt', 'JJ'), ('heel', 'NN'), ('mooi', 'RB'), ('#', '#'), ('widm', 'NN')]),
#        list([('Even', 'RB'), ('voor', 'JJ'), ('iedereen', 'JJ'), ('die', 'NN'), ('niet', 'JJ'), ('na', 'TO'), ('1x', 'CD'), ('uitleggen', 'NN'), ('de', 'FW'), ('spellen', 'FW'), ('snapt', 'NN'), ('.', '.'), ('Graag', 'NNP'), ('gedaan', 'NN'), ('.', '.'), ('#', '#'), ('Widm', 'NNP'), ('#', '#'), ('Widm2020', 'NNP'), ('#', '#'), ('Wieisdemol', 'NNP'), ('#', '#'), ('Wieisdemol2020', 'NNP'), ('https', 'NN'), (':', ':'), ('//t.co/TnTI8nFRZc', 'NN')]),
#        list([('Fuck', 'NNP'), ('merel', 'NN'), ('te', 'NN'), ('doorzichtig', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Gaat', 'NNP'), ('lekker', 'NN'), (',', ','), ('mijn', 'FW'), ('mol', 'FW'), ('al', 'NN'), ('in', 'IN'), ('eerste', 'NN'), ('uitzending', 'JJ'), ('naar', 'JJ'), ('huis', 'NN'), ('.', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Gelukkig', 'NNP'), (',', ','), ('mijn', 'NN'), ('mol', 'NN'), ('zit', 'NN'), ('er', 'NN'), ('nog', 'NN'), ('in', 'IN'), ('..', 'NNP'), ('maar', 'NN'), ('wat', 'NN'), ('een', 'JJ'), ('lauwe', 'JJ'), ('reacties', 'NNS'), ('bij', 'VBP'), ('die', 'JJ'), ('gasten', 'JJ'), ('joh', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Gewoon', 'NNP'), ('de', 'FW'), ('cijfercode', 'NN'), ('invoeren', 'NNS'), (',', ','), ('lijkt', 'VB'), ('me', 'PRP'), ('?', '.'), ('🤔', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Gewoon', 'NNP'), ('iedereen', 'NN'), ('een', 'JJ'), ('random', 'JJ'), ('naam', 'JJ'), ('geven', 'NN'), ('.', '.'), ('Wat', 'NNP'), ('een', 'JJ'), ('briljante', 'NN'), ('oplossing.😂😂😂', 'RB'), ('#', '#'), ('widm', 'NN')]),
#        list([('Google', 'NNP'), ('maps', 'NNS'), ('gebruiken', 'VBP'), ('mag', 'JJ'), ('blijkbaar', 'NN'), ('niet', 'JJ'), ('😂', 'NNP'), ('#', '#'), ('widm', 'NN')]),
#        list([('Grote', 'NNP'), ('vraag', 'NN'), ('is', 'VBZ'), ('nu', 'JJ'), ('natuurlijk', 'NNS'), (':', ':'), ('wat', 'NN'), ('gaan', 'NN'), ('al', 'NN'), ('die', 'NN'), ('mollen', 'VBN'), ('nog', 'JJ'), ('meer', 'NN'), ('doen', 'NN'), ('dit', 'NN'), ('seizoen', 'NN'), ('?', '.'), ('Komen', 'NNP'), ('niet', 'JJ'), ('voor', 'NN'), ('een', 'JJ'), ('uurtje', 'JJ'), ('naar', 'NN'), ('Italië', 'NNP'), ('..', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Had', 'NNP'), ('Rob', 'NNP'), ('nou', 'JJ'), ('lucifers', 'NNS'), ('op', 'VBP'), ('zijn', 'CD'), ('hoed', 'JJ'), ('tijdens', 'NNS'), ('de', 'IN'), ('finaletest', 'JJS'), ('?', '.'), ('Of', 'IN'), ('was', 'VBD'), ('dat', 'JJ'), ('altijd', 'NN'), ('al', 'NN'), ('zo', 'NNP'), ('🤔', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Hahahah', 'NNP'), ('Buddy', 'NNP'), ('die', 'VBP'), ('heel', 'NN'), ('droog', 'NN'), ('Nederlands', 'NNP'), ('praat', 'VBZ'), ('door', 'NN'), ('die', 'NN'), ('microfoon', 'NN'), ('.', '.'), ('Wat', 'NNP'), ('een', 'JJ'), ('heerlijke', 'NN'), ('gozer', 'NN'), ('is', 'VBZ'), ('het', 'JJ'), ('toch', 'RB'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('He', 'PRP'), (',', ','), ('heb', 'VBZ'), ('je', 'NN'), ('die', 'NN'), ('twee', 'VBP'), ('weer', 'NN'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Heb', 'NNP'), ('al', 'NN'), ('een', 'NN'), ('idee', 'NN'), ('.', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Het', 'NNP'), ('begon', 'NN'), ('de', 'FW'), ('zonen👼👼van', 'FW'), ('de', 'FW'), ('ware', 'FW'), ('God💚🦢op', 'NNP'), ('te', 'NN'), ('vallen🤔🐍🗣️😈🤦\u200d♂️hoe', 'NN'), ('mooi😍de', 'NN'), ('dochters', 'NNS'), ('van', 'VBP'), ('de', 'IN'), ('mensen👱🏽\u200d♀️👩🏻\u200d🦰👩🏿\u200d🦱waren-Gen.', 'JJ'), ('6:2', 'CD'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('FORaz', 'NNP'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('S04SVW', 'NNP'), ('#', '#'), ('wkwielrennen', 'JJ'), ('#', '#'), ('kvmstv', 'JJ'), ('#', '#'), ('مليون_تحية_للجلابية', 'JJ'), ('#', '#'), ('SaraAliKhan', 'NNP'), ('#', '#'), ('Caturday', 'NNP'), ('#', '#'), ('kaagent', 'JJ'), ('#', '#'), ('vanboekel', 'JJ'), ('#', '#'), ('TikTok', 'NNP'), ('#', '#'), ('Eredivisie', 'NNP'), ('#', '#'), ('Bundesliga', 'NNP')]),
#        list([('Het', 'NNP'), ('fijne', 'VBP'), ('van', 'JJ'), ('#', '#'), ('widm', 'NN'), ('is', 'VBZ'), ('dat', 'JJ'), ('er', 'NN'), ('en', 'IN'), ('x', 'NNP'), ('geen', 'JJ'), ('jankende', 'NN'), ('presentatoren', 'NN'), ('presenteren', 'NN'), ('.', '.'), ('Bijna', 'NNP'), ('dagelijkse', 'VBZ'), ('kost', 'FW'), ('op', 'JJ'), ('tv', 'NN'), ('emo', 'NN'), ('tv', 'NN'), ('graag', 'NN'), ('zonder', 'NN'), ('de', 'IN'), ('emoties', 'NNS'), ('van', 'VBP'), ('diegene', 'NN'), ('die', 'NN'), ('er', 'JJ'), ('voor', 'NN'), ('betaald', 'NN'), ('worden', 'JJ'), ('te', 'NN'), ('presenteren', 'NN'), ('of', 'IN'), ('te', 'NN'), ('interviewen', 'NN'), ('ergo', 'NN'), ('ik', 'NN'), ('zit', 'NN'), ('niet', 'JJ'), ('op', 'JJ'), ('hun', 'NN'), ('emo', 'NN'), ('hoofd', 'NN'), ('in', 'IN'), ('beeld', 'NN'), ('te', 'NN'), ('wachten', 'NN')]),
#        list([('Het', 'NNP'), ('is', 'VBZ'), ('zo', 'JJ'), ('overduidelijk', 'JJ'), ('Renee', 'NNP'), (',', ','), ('dat', 'NN'), ('ik', 'NN'), ('nu', 'JJ'), ('denk', 'NN'), ('dat', 'NN'), ('het', 'NN'), ('Rocky', 'NNP'), ('is', 'VBZ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Hints', 'NNS'), ('en', 'VBP'), ('opvallende', 'JJ'), ('acties', 'NNS'), ('uit', 'VBP'), ('de', 'IN'), ('eerste', 'NN'), ('aflevering', 'VBG'), ('van', 'NN'), ('2020', 'CD'), ('met', 'VBD'), ('de', 'FW'), ('heerlijke', 'FW'), ('titel', 'NN'), ('afgeschermd', 'NN'), ('.', '.'), ('Maar', 'NNP'), ('wie', 'VBD'), ('ziet', 'JJ'), ('er', 'JJ'), ('nu', 'NN'), ('hier', 'NN'), ('te', 'NN'), ('mollen', 'VBN'), ('?', '.'), ('https', 'NN'), (':', ':'), ('//t.co/1AV0rvuyTV', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/bzPRC9NhyP', 'NN')]),
#        list([('Holleeeeeeeee', 'NNP'), ('#', '#'), ('widm', 'NN'), ('Ik', 'NNP'), ('wist', 'NN'), ('‘', 'NNP'), ('t', 'NN'), (',', ','), ('ik', 'JJ'), ('wist', 'NN'), ('‘', 'NNP'), ('t', 'NN'), ('@', 'NNP'), ('jeroenkidv', 'VBZ'), ('GE-NI-AAL', 'JJ'), ('!', '.'), ('!', '.'), ('!', '.')]),
#        list([('IK', 'NNP'), ('HEB', 'NNP'), ('70', 'CD'), ('FK', 'NNP'), ('PUNTEN', 'NNP'), ('OP', 'NNP'), ('HEM', 'NNP'), ('INGEZET', 'NNP'), ('NEE', 'NNP'), ('#', '#'), ('widm', 'NN')]),
#        list([('Ieder', 'NNP'), ('seizoen', 'NN'), ('vliegt', 'NN'), ('#', '#'), ('kpn', 'NN'), ('interactieve', 'VBP'), ('tv', 'NN'), ('eruit', 'NN'), ('?', '.'), ('Waar', 'NNP'), ('slaat', 'VBD'), ('dat', 'JJ'), ('op', 'NN'), ('?', '.'), ('#', '#'), ('budget', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Iedereen', 'NNP'), ('heeft', 'VBD'), ('het', 'NN'), ('over', 'IN'), ('de', 'FW'), ('rode', 'FW'), ('jurk', 'NN'), ('van', 'NN'), ('mil', 'NN'), ('...', ':'), ('maar', 'NN'), ('waarom', 'IN'), ('heeft', 'NN'), ('Rob', 'NNP'), ('een', 'JJ'), ('rode', 'NN'), ('ballon', 'NN'), ('vast', 'JJ'), ('na', 'TO'), ('de', 'VB'), ('opdracht', 'FW'), ('met', 'FW'), ('de', 'FW'), ('auto', 'NN'), ('’', 'FW'), ('s', 'NN'), ('?', '.'), ('!', '.'), ('Waar', 'NNP'), ('rood', 'VBD'), ('duidelijk', 'NNS'), ('een', 'JJ'), ('‘', 'NNP'), ('hint', 'NN'), ('’', 'NN'), ('was', 'VBD'), ('!', '.'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/NHtnCMjmS2', 'NN')]),
#        list([('Iemand', 'NNP'), ('die', 'VB'), ('me', 'PRP'), ('de', 'IN'), ('logica', 'FW'), ('van', 'FW'), ('de', 'FW'), ('puzzelopdracht', 'FW'), ('met', 'VBD'), ('die', 'NN'), ('vakken', 'FW'), ('kan', 'NN'), ('uitleggen', 'NN'), ('?', '.'), ('#', '#'), ('WIDM', 'NNP'), ('#', '#'), ('wieisdemol', 'NN')]),
#        list([('Ik', 'NNP'), ('ben', 'NN'), ('nu', 'RB'), ('vooral', 'JJ'), ('geïnteresseerd', 'NN'), ('in', 'IN'), ('de', 'FW'), ('backstory', 'FW'), ('van', 'FW'), ('de', 'FW'), ('man', 'NN'), ('met', 'VBD'), ('geel', 'JJ'), ('zwarte', 'NNP'), ('trui', 'NN'), ('die', 'NN'), ('lekker', 'NN'), ('achter', 'NN'), ('de', 'IN'), ('groep', 'FW'), ('aan', 'JJ'), ('het', 'NN'), ('ontbijten', 'NN'), ('was', 'VBD'), ('.', '.'), ('Wat', 'NNP'), ('drijft', 'VBD'), ('hem', 'NN'), (',', ','), ('wie', 'NN'), ('is', 'VBZ'), ('de', 'JJ'), ('mol', 'FW'), ('van', 'NN'), ('zijn', 'NN'), ('leven', 'VBN'), ('?', '.'), ('?', '.'), ('?', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Ik', 'NNP'), ('denk', 'NN'), ('niet', 'JJ'), ('dat', 'JJ'), ('Mil', 'NNP'), ('de', 'FW'), ('Mol', 'NNP'), ('is', 'VBZ'), ('.', '.'), ('Zou', 'NNP'), ('ze', 'NNP'), ('dan', 'NN'), ('namelijk', 'JJ'), ('ook', 'NN'), ('de', 'IN'), ('opdracht', 'FW'), ('met', 'FW'), ('die', 'FW'), ('brug', 'FW'), ('overslaan', 'FW'), ('?', '.'), ('Als', 'NNP'), ('ze', 'NN'), ('mol', 'NN'), ('is', 'VBZ'), ('weet', 'JJ'), ('ze', 'JJ'), ('dit', 'NN'), ('toch', 'NN'), ('van', 'NN'), ('tevoren', 'NN'), ('?', '.'), ('#', '#'), ('WIDM', 'NNP')]),
#        list([('Ik', 'NNP'), ('eet', 'VBZ'), ('chips', 'NNS'), ('en', 'IN'), ('kijk', 'NN'), ('#', '#'), ('widm', 'NN'), ('Versta', 'NNP'), ('er', 'NN'), ('geen', 'NN'), ('kut', 'NN'), ('van', 'NN'), ('😂', 'NN')]),
#        list([('Ik', 'NNP'), ('erger', 'NN'), ('mij', 'NN'), ('echt', 'NN'), ('kapot', 'NN'), ('aan', 'NN'), ('@', 'NNP'), ('leonieterbraak', 'NN'), ('man', 'NN'), ('man', 'NN'), ('....', 'VBZ'), ('Ik', 'NNP'), ('hoop', 'NN'), ('dat', 'NN'), ('je', 'NN'), ('dat', 'NN'), ('onnozel', 'NN'), ('gedrag', 'NN'), ('speelt', 'VBD'), ('en', 'FW'), ('de', 'FW'), ('Mol', 'NNP'), ('bent', 'NN'), ('want', 'VBP'), ('dat', 'NN'), ('kan', 'NN'), ('haast', 'NN'), ('niet', 'JJ'), ('anders', 'NNS'), ('🙏', 'VBP'), ('#', '#'), ('widm', 'NN')]),
#        list([('Ik', 'NNP'), ('geloof', 'NN'), ('je', 'NN'), ("'voor", 'POS'), ('geen', 'JJ'), ('meter', 'NN'), ("'", 'POS'), ('.', '.'), ('Buddy', 'NNP'), ('is', 'VBZ'), ('toch', 'JJ'), ('niet', 'JJ'), ('de', 'FW'), ('mol', 'FW'), ('?', '.'), ('Zou', 'NNP'), ('ik', 'NN'), ('dus', 'NN'), ('echt', 'VBP'), ('niet', 'JJ'), ('tof', 'JJ'), ('vinden', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Ik', 'NNP'), ('had', 'VBD'), ('ook', 'VBN'), ('gehoopt', 'JJ'), ('dat', 'NN'), ('Jamie', 'NNP'), ('er', 'NN'), ('in', 'IN'), ('bleef', 'NN'), ('gewoon', 'NN'), ('omdat', 'NN'), ('hij', 'NN'), ('BIZAR', 'NNP'), ('knap', 'NN'), ('is', 'VBZ'), (',', ','), ('dat', 'NN'), ('we', 'PRP'), ('dan', 'VBP'), ('nog', 'JJ'), ('allemaal', 'NN'), ('naar', 'IN'), ('hem', 'JJ'), ('konden', 'FW'), ('kijken', 'FW'), ('en', 'FW'), ('konden', 'FW'), ('wegdromen', 'NNS'), ('en', 'VBP'), ('dan', 'JJ'), ('helemaal', 'NN'), ('niet', 'JJ'), ('meer', 'NN'), ('op', 'NN'), ('het', 'NN'), ('daadwerkelijke', 'NN'), ('programma', 'NN'), ('zouden', 'NNP'), ('letten', 'VBZ'), ('totdat', 'JJ'), ('je', 'NNS'), ('weer', 'VBP'), ('wakker', 'NN'), ('schoot', 'NN'), ('...', ':'), ('maar', 'NN'), ('goed', 'NN'), (',', ','), ('niks', 'FW'), ('is', 'VBZ'), ('minder', 'JJR'), ('waar', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Ik', 'NNP'), 
 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('widm2019', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Jamie', 'NNP'), ('is', 'VBZ'), ('eruit', 'NN'), ('...', ':'), ('Ik', 'NNP'), ('zit', 'NNP'), ('echt', 'NN'), ('nogsteeds', 'NNS'), ('helemaal', 'VBP'), ('in', 'IN'), ('shock', 'NN'), ('...', ':'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Jammer', 'NN'), ('he', 'PRP'), ('?', '.'), ('Zoveel', 'NNP'), ('sjeu', 'RB'), ('#', '#'), ('widm', 'NN')]),
#        list([('Johan', 'NNP'), ('komt', 'VBZ'), ('snel', 'NNS'), ('met', 'VBD'), ('wie', 'NN'), ('is', 'VBZ'), ('de', 'IN'), ('mol', 'FW'), ('met', 'FW'), ('vraagteken', 'NN'), ('!', '.'), ('Doet', 'NNP'), ('de', 'IN'), ('mol', 'FW'), ('niet', 'JJ'), ('.', '.'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('widm2020', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('@', 'NN'), ('WieIsDeMol', 'NNP')]),
#        list([('Johan', 'NNP'), ('showt', 'VBD'), ('z', 'NNP'), ('’', 'NNP'), ('n', 'JJ'), ('joker', 'NN'), ('aan', 'NN'), ('iedereen', 'NN'), ('.', '.'), ('Aparte', 'NNP'), ('keuze', 'NN'), (',', ','), ('al', 'NN'), ('is', 'VBZ'), ('een', 'JJ'), ('joker', 'NN'), ('ook', 'NN'), ('weer', 'NN'), ('niet', 'JJ'), ('zó', 'NNP'), ('waardevol', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('Jongens', 'NNS'), ('.', '.'), ('Hier', 'NNP'), ('gaat', 'JJ'), ('iets', 'NNS'), ('fout', 'RB'), ('.', '.'), ('Nu', 'NNP'), ('al', 'JJ'), ('zoveel', 'NNP'), ('geld', 'VBD'), ('verdiend', 'NN'), ('.', '.'), ('En', 'NNP'), ('Ellie', 'NNP'), ('is', 'VBZ'), ('er', 'JJ'), ('niet', 'JJ'), ('eens', 'NNS'), ('bij', 'NN'), ('.', '.'), ('Ik', 'NNP'), ('ben', 'NN'), ('nu', 'NN'), ('volledig', 'NN'), ('in', 'IN'), ('de', 'NNP'), ('war', 'NN'), ('!', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('LAVEZZI', 'NNP'), ('is', 'VBZ'), ('er', 'JJ'), ('toch', 'JJ'), ('wel', 'NN'), ('bij', 'NN'), ('tijdens', 'VBZ'), ('de', 'IN'), ('Finale', 'NNP'), ('?', '.'), ('#', '#'), ('WieIsDeMol', 'NNP'), ('#', '#'), ('WIDM', 'NNP'), ('#', '#'), ('MolTalk', 'NNP')]),
# ...
#        list([('Vanavond', 'NNP'), ('om', 'PRP'), ('19.00', 'CD'), ('gaat', 'NN'), ('de', 'FW'), ('verzamelvideo', 'NN'), ('in', 'IN'), ('première', 'NN'), ('op', 'NN'), ('YouTube', 'NNP'), ('(', '('), ('https', 'NN'), (':', ':'), ('//t.co/8Oc2VCB2Tb', 'NN'), (')', ')'), ('Zelf', 'NNP'), ('zal', 'NNP'), ('ik', 'NN'), ('in', 'IN'), ('de', 'FW'), ('chat', 'FW'), ('aanwezig', 'FW'), ('zijn', 'NN'), (',', ','), ('zodat', 'NN'), ('we', 'PRP'), ('ook', 'VBP'), ('jouw', 'JJ'), ('bevindingen', 'NN'), ('kunnen', 'NN'), ('bespreken', 'VBN'), ('😊', 'NNP'), ('Tot', 'NNP'), ('vanavond', 'NN'), ('?', '.'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/iu4rAmDTeU', 'NN')]),
#        list([('Verkeerde', 'NNP'), ('hashtags', 'NN'), ('!', '.'), ('Moest', 'NNP'), ('natuurlijk', 'RB'), ('#', '#'), ('widm', 'JJ'), ('zijn', 'NN'), ('.', '.'), ('#', '#'), ('moltalk', 'NN'), ('https', 'NN'), (':', ':'), ('//t.co/Sqabq1CAZC', 'NN')]),
#        list([('Vol', 'NN'), ('!', '.'), ('Succes', 'NNPS'), ('allen', 'VBP'), ('in', 'IN'), ('de', 'FW'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('WidN', 'NNP'), ('poule', 'NN'), ('!', '.'), ('De', 'NNP'), ('prijs', 'FW'), ('maak', 'NN'), ('ik', 'NN'), ('ergens', 'VBZ'), ('halverwege', 'JJ'), ('bekend', 'NN'), ('😉', 'NN')]),
#        list([('Volgende', 'NNP'), ('week', 'NN'), ('komt', 'NN'), ('Evi', 'NNP'), ('terug', 'NN'), ('en', 'NN'), ('is', 'VBZ'), ('zij', 'JJ'), ('gewoon', 'NN'), ('de', 'IN'), ('Mol', 'NNP'), ('!', '.'), ('En', 'NNP'), ('terecht', 'NN'), ('!', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Volgens', 'NNS'), ('mij', 'VBP'), ('zag', 'CD'), ('ik', 'JJ'), ('Dennis', 'NNP'), ('Weening', 'NNP'), ('lopen', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Volgens', 'NNS'), ('mij', 'VBP'), ('zag', 'CD'), ('ik', 'JJ'), ('Tygo', 'NNP'), ('juist', 'NN'), ('vaten', 'NN'), ('omdraaien', 'JJ'), ('met', 'VBD'), ('de', 'FW'), ('letters', 'NNS'), ('naar', 'VBP'), ('beneden', 'VBN'), ('?', '.'), ('😶', 'JJ'), ('#', '#'), ('WIDM', 'NNP')]),
#        list([('Voor', 'NNP'), ('de', 'FW'), ('laatste', 'FW'), ('keer', 'NN'), (':', ':'), ('Wie', 'NNP'), ('is', 'VBZ'), ('.......', 'NNP'), ('De', 'NNP'), ('Mol', 'NNP'), ('?', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Voor', 'NNP'), ('een', 'JJ'), ('journalist', 'NN'), ('en', 'IN'), ('een', 'JJ'), ('schrijver', 'NN'), ('zijn', 'NN'), ('Charlotte', 'NNP'), ('en', 'VBZ'), ('Splinter', 'NNP'), ('taalkundig', 'NN'), ('niet', 'JJ'), ('echt', 'NN'), ('sterk', 'NN'), ('in', 'IN'), ('dit', 'NN'), ('spel', 'NN'), ('...', ':'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Waaaaaaaaah', 'NNP'), ('tegen', 'NN'), ('de', 'FW'), ('mol', 'FW'), ('!', '.'), ('Goed', 'NNP'), ('opletten', 'JJ'), ('wie', 'JJ'), ('eerder', 'NN'), ('of', 'IN'), ('later', 'JJ'), ('bij', 'NN'), ('t', 'NN'), ('groepje', 'NN'), ('weggaat', 'NN'), ('.', '.'), ('Ben', 'NNP'), ('benieuwd', 'JJ'), ('wie', 'NN'), ('de', 'IN'), ('mol', 'FW'), ('mag', 'FW'), ('beschieten', 'NN'), ('!', '.'), ('Als', 'NNP'), ('in', 'IN'), ('dat', 'NN'), ('de', 'FW'), ('mol', 'FW'), ('de', 'FW'), ('loods', 'FW'), ('inmoet', 'NN'), ('gaan', 'NN'), ('he', 'PRP'), ('...', ':'), ('#', '#'), ('widm', 'NN')]),
#        list([('Waar', 'NNP'), ('heb', 'NN'), ('je', 'NN'), ('krullen', 'VBN'), ('voor', 'JJ'), ('nodig', 'JJ'), ('als', 'NNS'), ('je', 'VBP'), ('je', 'NN'), ('haar', 'NN'), ('in', 'IN'), ('zo', 'NN'), ('’', 'NNP'), ('n', 'CC'), ('strakke', 'JJ'), ('staart', 'NN'), ('doet', 'NN'), ('?', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Waarom', 'IN'), ('zijn', 'NNP'), ('er', 'VBP'), ('geen', 'JJ'), ('hints', 'NNS'), ('en', 'IN'), ('theorieën', 'NN'), ('dit', 'NN'), ('jaar', 'NN'), (':', ':'), ('(', '('), ('#', '#'), ('widm', 'NN')]),
#        list([('Wat', 'NNP'), ('een', 'JJ'), ('gave', 'VBD'), ('opdracht', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('@', 'NN'), ('WieIsDeMol', 'NNP')]),
#        list([('Wat', 'NNP'), ('een', 'JJ'), ('leuke', 'NN'), ('opdrachten', 'VBP'), ('bij', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('vanavond', 'NN'), ('!', '.'), ('!', '.'), ('❤️❤️❤️', 'NN')]),
#        list([('Wat', 'NNP'), ('heeft', 'VBD'), ('Tycho', 'NNP'), ('toch', 'NN'), ('met', 'VBD'), ('die', 'JJ'), ('beweging', 'VBG'), ('bij', 'NN'), ('de', 'IN'), ('lazeropdracht', 'FW'), ('.', '.'), ('✌🏼👨✌🏼', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('We', 'PRP'), ('kunnen', 'VBP'), ('!', '.'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/HwvSFCyTNG', 'NN')]),
#        list([('Weer', 'NNP'), ('geprobeerd', 'NN'), ('maar', 'NN'), ('nu', 'JJ'), ('al', 'NN'), ('de', 'IN'), ('draad', 'FW'), ('kwijt', 'NN'), ('.', '.'), ('Volgend', 'NNP'), ('jaar', 'NN'), ('weer', 'NN'), ('een', 'IN'), ('poging', 'VBG'), ('.', '.'), ('Misschien', 'NNP'), ('.', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('allemaalgedoe', 'NN')]),
#        list([('Weer', 'NNP'), ('lekkere', 'EX'), ('filmmuziek', 'JJ'), ('bij', 'NN'), ('#', '#'), ('widm', 'NN'), ('Crouching', 'NNP'), ('Tiger', 'NNP'), (',', ','), ('Hidden', 'NNP'), ('Dragon', 'NNP')]),
#        list([('Wel', 'NNP'), ('gelukkig', 'NN'), ('nog', 'NN'), ('steeds', 'NNS'), ('al', 'VBP'), ('mijn', 'RB'), ('beginpunten', 'VBN'), ('😁', 'NNP'), ('Benieuwd', 'NNP'), ('hoe', 'NN'), ('lang', 'NN'), ('dat', 'NN'), ('nog', 'NN'), ('goed', 'NN'), ('gaat', 'NN'), (',', ','), ('want', 'VBP'), ('heb', 'JJ'), ('niet', 'JJ'), ('echt', 'NN'), ('een', 'JJ'), ('idee', 'NN'), ('nog', 'JJ'), ('..', 'NNP'), ('#', '#'), ('Widm', 'NNP'), ('#', '#'), ('Moltalk', 'NNP')]),
#        list([('Wel', 'NNP'), ('knap', 'NNP'), ('dat', 'NN'), ('#', '#'), ('widm', 'NN'), ('na', 'RB'), ('20', 'CD'), ('jaar', 'NN'), ('nog', 'NN'), ('steeds', 'NNS'), ('heel', 'VBP'), ('televisiekijkend', 'JJ'), ('Nederland', 'NNP'), ('in', 'IN'), ('haar', 'JJ'), ('ban', 'NN'), ('kan', 'NN'), ('houden', 'NN')]),
#        list([('Whaaaa', 'NN'), ('!', '.'), ('!', '.'), ('!', '.'), ('Wat', 'NNP'), ('een', 'JJ'), ('aflevering', 'VBG'), ('!', '.'), ('!', '.'), ('😱😱😱', 'JJ'), ('Maar', 'NNP'), (':', ':'), ('alle', 'NN'), ('punten', 'VBZ'), ('nog', 'JJ'), ('!', '.'), ('!', '.'), ('Whooohooo', 'UH'), ('!', '.'), ('!', '.'), ('🎉🎉', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/64jdUNXfqc', 'NN')]),
#        list([('Wie', 'NNP'), ('is', 'VBZ'), ('de', 'FW'), ('Mol', 'NNP'), ('?', '.'), ('#', '#'), ('WieisdeMol', 'NNP'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('MolTalk', 'NN')]),
#        list([('Wie', 'NNP'), ('is', 'VBZ'), ('de', 'FW'), ('Mol', 'NNP'), ('?', '.'), ('|', 'NN'), ('Aflevering', 'VBG'), ('6', 'CD'), ('|', 'JJ'), ('2019', 'CD'), ('https', 'NN'), (':', ':'), ('//t.co/x1Fpv4lSSj', 'JJ'), ('#', '#'), ('vrouwen', 'JJ'), ('#', '#'), ('WieIsDeMol', 'NNP'), ('#', '#'), ('WIDM', 'NNP')]),
#        list([('Wie', 'NNP'), ('is', 'VBZ'), ('de', 'FW'), ('Mol', 'NNP'), ('volgens', 'NNS'), ('Robin', 'NNP'), ('Juste', 'NNP'), ('?', '.'), ('Ramon', 'NNP'), ('sprak', 'VBD'), ('met', 'VBN'), ('deze', 'JJ'), ('deelnemer', 'NN'), ('van', 'NN'), ('De', 'NNP'), ('Mol', 'NNP'), ('2017', 'CD'), ('over', 'IN'), ('zijn', 'NN'), ('deelname', 'NN'), ('en', 'IN'), ('zijn', 'NNP'), ('verdenkingen', 'NN'), ('#', '#'), ('demol', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/oovUfriHah', 'NN')]),
#        list([('Wij', 'NNP'), ('lopen', 'JJ'), ('tenminste', 'NN'), ('niet', 'JJ'), ('te', 'NN'), ('zeiken', 'NN'), ('!', '.'), ('😆', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('Wow', 'NNP'), ('Splinter', 'NNP'), ('die', 'NN'), ('was', 'VBD'), ('slim', 'JJ'), ('gevonden', 'NN'), ('...', ':'), ('Of', 'IN'), ('alweer', 'NN'), ('voorkennis', 'NN'), ('en', 'FW'), ('is', 'VBZ'), ('niets', 'NNS'), ('wat', 'JJ'), ('het', 'JJ'), ('lijkt', 'NN'), (':', ':'), ('O', 'NN'), ('?', '.'), ('...', ':'), ('#', '#'), ('MolTalk', 'NNP'), ('#', '#'), ('Mollenstreken', 'NNP'), ('#', '#'), ('MolLootje', 'NNP'), ('#', '#'), ('WIDM', 'NNP'), ('#', '#'), ('MolTheorie', 'NNP'), ('#', '#'), ('Splinter', 'NNP'), ('#', '#'), ('SlimGedaan', 'NNP')]),
#        list([('Yes', 'UH'), ('!', '.'), ('M', 'NNP'), ('’', 'NNP'), ('n', 'FW'), ('tunnelvisie', 'NN'), ('was', 'VBD'), ('dus', 'JJ'), ('terecht', 'NN'), ('.', '.'), ('Rob', 'NNP'), ('is', 'VBZ'), ('de', 'JJ'), ('mol', 'FW'), ('!', '.'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/Le5rC52v0a', 'NN')]),
#        list([('Yes', 'UH'), ('mijn', 'NN'), ('mol', 'NN'), ('merel', 'NN'), ('zit', 'NN'), ('er', 'NN'), ('nog', 'NN'), ('in', 'IN'), ('.', '.'), ('Spannend', 'NN'), ('!', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('Zei', 'NNP'), ('Rob', 'NNP'), ('nou', 'MD'), ('Merel', 'NNP'), ('ipv', 'VB'), ('Mil', 'NNP'), ('?', '.'), ('Heeft', 'NNP'), ('hij', 'VBZ'), ('meer', 'NN'), ('versprekingen', 'NN'), ('gehad', 'VBD'), ('als', 'NNS'), ('verwijzing', 'VBG'), ('naar', 'JJ'), ("'oude", 'NNP'), ("'", 'POS'), ('mollen', 'NN'), ('?', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('Zet', 'NNP'), ('Renée', 'NNP'), ('in', 'IN'), ('WIDM', 'NNP'), ('de', 'FW'), ('rest', 'FW'), ('voor', 'NN'), ('joker', 'NN'), ('met', 'VBD'), ('deze', 'JJ'), ('opvallende', 'NN'), ('actie', 'NN'), ('?', '.'), ('https', 'NN'), (':', ':'), ('//t.co/CMOd4xPCQj', 'JJ'), ('#', '#'), ('vrouwen', 'JJ'), ('#', '#'), ('WieIsDeMol', 'NNP'), ('#', '#'), ('WIDM', 'NNP')]),
#        list([('Zie', 'NNP'), ('je', 'NN'), ('ze', 'NN'), ('al', 'NN'), ('rennen', 'NN'), ('?', '.'), ('?', '.'), ('Politieagenten', 'NNP'), ('met', 'VBD'), ('pijl', 'JJ'), ('en', 'IN'), ('boog', 'NN'), ('?', '.'), ('?', '.'), ('#', '#'), ('widm', 'JJ'), ('https', 'NN'), (':', ':'), ('//t.co/5BVftbz4YQ', 'NN')]),
#        list([('Zijn', 'NNP'), ('de', 'FW'), ('bekende', 'FW'), ('bn-ers', 'NNS'), ('op', 'IN'), ('?', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('``', '``'), ('Hier', 'NNP'), ('is', 'VBZ'), ('ontzettend', 'JJ'), ('gemold', 'NN'), ('!', '.'), ("''", "''"), ('-', ':'), ('je', 'NN'), ('verwacht', 'NN'), ('het', 'NN'), ('niet', 'JJ'), ('in', 'IN'), ('dit', 'NN'), ('programma', 'NN'), ('he', 'PRP'), ('#', '#'), ('widm', 'NN')]),
#        list([('altijd', 'JJ'), ('voor', 'NN'), ('je', 'NN'), ('eerste', 'NN'), ('gevoel', 'NN'), ('gaan', 'NN'), (',', ','), ('dus', 'NN'), ('i', 'NN'), ('guess', 'NN'), ('dat', 'NN'), ('t', 'NN'), ('nikkie', 'NN'), ('is', 'VBZ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'JJ'), ('#', '#'), ('moltalk', 'NN'), 
 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN'), ('https', 'NN'), (':', ':'), ('//t.co/1NYcIfpKdw', 'NN')]),
#        list([('onrust', 'RB'), ('stoken', 'VBN'), ('?', '.'), ('?', '.'), ('wat', 'NN'), ('?', '.'), ('?', '.'), ('?', '.'), ('😳', 'JJ'), ('#', '#'), ('widm', 'NN')]),
#        list([('renee', 'NN'), ('=', 'NNP'), ('mol', 'NN'), ('die', 'NN'), ('publiekelijk', 'NN'), ('molt', 'NN'), ('rocky', 'JJ'), ('=', 'NNP'), ('de', 'FW'), ('officiële', 'FW'), ('mol', 'FW'), ('mark', 'NN'), ('my', 'PRP$'), ('words', 'NNS'), ('.', '.'), ('#', '#'), ('widm', 'NN'), ('(', '('), ('en', 'JJ'), ('zo', 'NN'), ('niet', 'JJ'), (',', ','), ('kom', 'JJ'), ('terug', 'NN'), ('naar', 'NN'), ('deze', 'NN'), ('tweet', 'NN'), ('en', 'IN'), ('lach', 'FW'), ('me', 'PRP'), ('uit', 'NN'), (',', ','), ('het', 'NN'), ('is', 'VBZ'), ('oke', 'VBN'), (')', ')')]),
#        list([('we', 'PRP'), ('zijn', 'VBP'), ('nu', 'JJ'), ('al', 'NN'), ('gewoon', 'NN'), ('bij', 'NN'), ('de', 'IN'), ('test', 'FW'), ('jdndknc', 'NN'), ('#', '#'), ('widm', 'NN')]),
#        list([('wel', 'NN'), ('knap', 'NN'), ('van', 'NN'), ('buddy', 'NN'), ('dat', 'NN'), ('ie', 'NN'), ('zichzelf', 'PRP'), ('kan', 'VBP'), ('bellen', 'JJ'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('“', 'JJ'), ('Ron', 'NNP'), ('Boszhard', 'NNP'), (',', ','), ('nota', 'JJ'), ('bene', 'NN'), ('uit', 'NN'), ('een', 'JJ'), ('ander', 'NN'), ('seizoen', 'NN'), (',', ','), ('is', 'VBZ'), ('de', 'JJ'), ('mol', 'NN'), ('!', '.'), ('”', 'JJ'), ('Wat', 'NNP'), ('een', 'JJ'), ('plottwist', 'NN'), ('zou', 'NN'), ('dát', 'NN'), ('zijn', 'NN'), ('.', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('wieisdemol', 'NN')]),
#        list([('“', 'JJ'), ('Waar', 'NNP'), ('is', 'VBZ'), ('dit', 'JJ'), ('misgegaan', 'NN'), ('?', '.'), ('”', 'JJ'), ('Nou', 'NNP'), ('Marije', 'NNP'), (',', ','), ('dat', 'NN'), ('vraag', 'NN'), ('ik', 'NN'), ('mij', 'NN'), ('ook', 'NN'), ('af', 'NN'), ('wanneer', 'NN'), ('ik', 'NN'), ('elke', 'JJ'), ('ochtend', 'NN'), ('in', 'IN'), ('de', 'FW'), ('spiegel', 'FW'), ('kijk', 'FW'), ('.', '.'), ('#', '#'), ('widm', 'NN')]),
#        list([('“', 'NN'), ('De', 'NNP'), ('mol', 'NN'), ('is', 'VBZ'), ('nog', 'JJ'), ('lang', 'JJ'), ('niet', 'JJ'), ('klaar', 'NN'), ('met', 'VBD'), ('ZIJN', 'NNP'), ('werk', 'NN'), ('”', 'NNP'), (',', ','), ('zegt', 'NNP'), ('Rik', 'NNP'), ('.', '.'), ('Hij', 'NNP'), ('had', 'VBD'), ('ook', 'VBN'), ('zijn/haar', 'NNP'), ('werk', 'JJ'), ('kunnen', 'NN'), ('zeggen', 'NN'), ('.', '.'), ('#', '#'), ('widm', 'JJ'), ('#', '#'), ('moltalk', 'NN')]),
#        list([('“', 'NN'), ('Dit', 'NNP'), ('is', 'VBZ'), ('een', 'JJ'), ('tiet', 'JJ'), ('”', 'NN'), ('is', 'VBZ'), ('mijn', 'JJ'), ('nieuwe', 'JJ'), ('favoriete', 'JJ'), ('#', '#'), ('WIDM', 'NNP'), ('uitspraak', 'NN')])],
#       dtype=object)

# %%
unique, counts = np.unique([x[19] for x in features_widm], return_counts=True)
counts

#activity
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
unique, counts = np.unique([x[20] for x in features_widm], return_counts=True)
counts

#has profile pic
# Out:
# array([110842,  17575], dtype=int64)

# %%
unique, counts = np.unique([x[21] for x in features_widm], return_counts=True)
counts

#fpp
# Out:
# array([128417], dtype=int64)

# %%
unique, counts = np.unique([x[22] for x in features_widm], return_counts=True)
counts

#possibly sensitive
# Out:
# array([127449,    968], dtype=int64)

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs )
    kmeans.fit([x[0:17] for x in features_widm])
    sse.append(kmeans.inertia_)
    
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
scaled_features = [x[0:17] for x in features_widm]

# %%
kmeans = KMeans(n_clusters=3, **kmeans_kwargs )
labels = kmeans.fit_predict(scaled_features)

# %%
np.count_nonzero(labels == 1)
# Out:
# 22667

# %%
np.count_nonzero(labels == 2)
# Out:
# 60898

# %%
np.count_nonzero(labels == 0)
# Out:
# 44852

# %%
plt.style.use("fivethirtyeight")
plt.bar([0,1,2], [44852,22667,60898])
plt.xlabel("Cluster")
plt.ylabel("Tweets")
# Out:
# Text(0, 0.5, 'Tweets')

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

scaled_features2 = [x[0:17] for x in features_widm]
kmeans2 = KMeans(n_clusters=2, **kmeans_kwargs )
labels2 = kmeans.fit_predict(scaled_features2)

# %%
plt.style.use("fivethirtyeight")
zeros = np.count_nonzero(labels2 == 0)
ones = np.count_nonzero(labels2 == 1)
plt.bar([0,1], [zeros,ones])
plt.xlabel("Cluster")
plt.ylabel("Tweets")
plt.title("#WIDM")
# Out:
# Text(0.5, 1.0, '#WIDM')

# %%
import html
import re
from nltk.stem import WordNetLemmatizer
def function_clean_tweet(text):
    # Escaping HTML characters
    text = html.unescape(text)
    text = str(text)
    # Removal of URLs (three-parter because the word tokenizer splits URLs like that)
    text = re.sub("https", "", text)
    text = re.sub(":", "", text)
    text = re.sub("//[^\s]*", "", text)
    # Removal of mentions
    text = re.sub("@[^\s]*", "", text)
    # Removal of hashtags
    text = re.sub("#[^\s]*", "", text)
    # Convert to lowercase
    text = text.lower()
    lemmatizer = WordNetLemmatizer()
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
stop_words = set(stopwords.words('dutch'))
stop_words.add("widm")
stop_words.add("widm2020")
stop_words.add("wieisdemol")
stop_words.add("mol")
stop_words.add("moltalk")
stop_words.add("wieisdemol2020")
stop_words.add("widm2019")
stop_words.add("rt")

tweet_texts = [x[0]["text"] for x in data]

word_tokens = [word_tokenize(text, preserve_line=False) for text in tweet_texts]
 
filtered_sentences = [[w for w in tweet if not w.lower() in stop_words] for tweet in word_tokens]

all_words = [' '.join([x for x in f]) for f in filtered_sentences]
all_words = [function_clean_tweet([text]) for text in all_words]

count_vectorizer = CountVectorizer(stop_words=stop_words)
count_data = count_vectorizer.fit_transform(all_words)

lda = LDA(n_components=5, n_jobs=-1)
lda.fit(count_data)

print("Topics found via LDA:")
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
print_topics(lda, count_vectorizer, 20)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nickv\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Topics found via LDA:
#
# Topic #0:
# seizoen aflevering goede leonie zegt vind echt ellie waar niels één gepakt stok erg weer net gaan foto jeroen we
#
# Topic #1:
# splinter rob nathan rode tv even wel renee nooit iedereen buddy zit gewoon beeld claes mee chinees miljuschka vind volgens
#
# Topic #2:
# jaar aflevering finale buddy wel echt gaan joker tijdens weer heel zit wist knap steed zaterdag 20 eerste seizoen iedereen
#
# Topic #3:
# merel weer opdracht gaat sarah kandidaten huis man he eerste patrick jeroen zwart niels anders ingezet lekker ron app uitleggen
#
# Topic #4:
# we punten hint gaan alle weer zegt opdracht zat u200d mollenjacht via vanavond verdenkingen rob vrijstelling doet nathan eerste gelukkig

# %%
import pyLDAvis
import sklearn
import pyLDAvis.sklearn
#help(pyLDAvis)

pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, count_data, count_vectorizer)
# Out:
# C:\Users\nickv\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:232: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.209976  0.196405       1        1  25.418635
# 4      0.212785 -0.153162       2        1  21.173956
# 3     -0.106694 -0.256202       3        1  19.556194
# 2     -0.080658  0.091420       4        1  18.597630
# 0     -0.235410  0.121539       5        1  15.253585, topic_info=              Term         Freq        Total Category  logprob  loglift
# 830        seizoen  5479.000000  5479.000000  Default  30.0000  30.0000
# 292         finale  3466.000000  3466.000000  Default  29.0000  29.0000
# 807           rode  2854.000000  2854.000000  Default  28.0000  28.0000
# 783         punten  3840.000000  3840.000000  Default  27.0000  27.0000
# 354          goede  2017.000000  2017.000000  Default  26.0000  26.0000
# ...            ...          ...          ...      ...      ...      ...
# 481           kijk  1020.225157  3461.966343   Topic5  -4.9887   0.6585
# 1047  vrijstelling  1015.503809  3438.623059   Topic5  -4.9933   0.6607
# 310           gaan  1024.687229  5929.715510   Topic5  -4.9843   0.1248
# 1070          weer  1026.102128  8405.085586   Topic5  -4.9829  -0.2227
# 1065            we  1022.835066  6862.483177   Topic5  -4.9861  -0.0231
#
# [306 rows x 6 columns], token_table=      Topic      Freq    Term
# term
# 1         1  0.998736      10
# 4         1  0.998736     150
# 8         4  0.999425    1976
# 10        3  0.999183      1x
# 11        4  0.999368      20
# ...     ...       ...     ...
# 1154      4  0.999628    zoon
# 1161      3  0.999326   zwart
# 1162      2  0.999568  zwarte
# 1166      2  0.320950     één
# 1166      5  0.678072     één
#
# [418 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 5, 4, 3, 1])
